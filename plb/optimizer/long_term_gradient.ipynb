# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../..")
import plb
from plb.envs import make
import taichi as ti

env = make("Move-v1")

env.reset()
taichi_env = env.taichi_env
# Out:
# [Taichi] version 1.7.0, llvm 15.0.4, commit 2fd24490, linux, python 3.10.13
# [I 12/31/23 19:30:02.800 1035681] [shell.py:_shell_pop_print@23] Graphical python shell detected, using wrapped sys.stdout
# [Taichi] Starting on arch=cuda
# Building primitive
# action:
#   dim: 3
#   scale: (0.01, 0.01, 0.01)
# color: (0.7, 0.7, 0.7)
# friction: 0.9
# init_pos: (0.5757143040494873, 0.5619162002773135, 0.7515980438048129)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# radius: 0.03
# shape: Sphere
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 3
#   scale: (0.01, 0.01, 0.01)
# color: (0.7, 0.7, 0.7)
# friction: 0.9
# init_pos: (0.7757143040494873, 0.5619162002773135, 0.7515980438048129)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# radius: 0.03
# shape: Sphere
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# {'radius': 0.1024534880385289, 'init_pos': (0.6757143040494873, 0.5619162002773135, 0.7515980438048129), 'color': 8323072}
# Initialize Renderer
# bake_size: 6
# camera_pos: (0.5, 1.2, 4.0)
# camera_rot: (0.2, 0)
# dx: 0.006666666666666667
# image_res: (512, 512)
# light_direction: (2.0, 1.0, 0.7)
# max_num_particles: 1000000
# max_ray_depth: 2
# sdf_threshold: 0.20720000000000002
# spp: 50
# target_res: (64, 64, 64)
# use_directional_light: False
# use_roulette: False
# voxel_res: (168, 168, 168)
# [W 12/31/23 19:30:03.649 1035681]
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 737, in start
#     self.io_loop.start()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 524, in dispatch_queue
#     await self.process_one()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 513, in process_one
#     await dispatch(*args)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 418, in dispatch_shell
#     await result
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 758, in execute_request
#     reply_content = await reply_content
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 426, in do_execute
#     res = shell.run_cell(
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/user/22715/ipykernel_1035681/1064780290.py", line 7, in <module>
#     env = make("Move-v1")
#   File "/orion/u/yangyou/PlasticineLab/plb/optimizer/../../plb/envs/__init__.py", line 17, in make
#     env: PlasticineEnv = gym.make(env_name, nn=nn)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/gym/envs/registration.py", line 156, in make
#     return registry.make(id, **kwargs)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/gym/envs/registration.py", line 101, in make
#     env = spec.make(**kwargs)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/gym/envs/registration.py", line 73, in make
#     env = cls(**_kwargs)
#   File "/orion/u/yangyou/PlasticineLab/plb/optimizer/../../plb/envs/env.py", line 17, in __init__
#     self.taichi_env = TaichiEnv(cfg, nn) # build taichi environment
#   File "/orion/u/yangyou/PlasticineLab/plb/optimizer/../../plb/engine/taichi_env.py", line 32, in __init__
#     self.renderer = Renderer(cfg.RENDERER, self.primitives)
#   File "/orion/u/yangyou/PlasticineLab/plb/optimizer/../../plb/engine/renderer/renderer.py", line 77, in __init__
#     ti.root.dense(ti.ijk, (4, 4, 4)).dense(ti.ijk, [i//4 for i in self.voxel_res]).place(self.volume, self.sdf, self.sdf_copy, self.color_vec)
# Shape 42 is detected on non-first division of axis i. For best performance, we recommend that you set it to a power of two.
# [W 12/31/23 19:30:03.649 1035681]
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 737, in start
#     self.io_loop.start()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 524, in dispatch_queue
#     await self.process_one()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 513, in process_one
#     await dispatch(*args)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 418, in dispatch_shell
#     await result
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 758, in execute_request
#     reply_content = await reply_content
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 426, in do_execute
#     res = shell.run_cell(
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/user/22715/ipykernel_1035681/1064780290.py", line 7, in <module>
#     env = make("Move-v1")
#   File "/orion/u/yangyou/PlasticineLab/plb/optimizer/../../plb/envs/__init__.py", line 17, in make
#     env: PlasticineEnv = gym.make(env_name, nn=nn)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/gym/envs/registration.py", line 156, in make
#     return registry.make(id, **kwargs)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/gym/envs/registration.py", line 101, in make
#     env = spec.make(**kwargs)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/gym/envs/registration.py", line 73, in make
#     env = cls(**_kwargs)
#   File "/orion/u/yangyou/PlasticineLab/plb/optimizer/../../plb/envs/env.py", line 17, in __init__
#     self.taichi_env = TaichiEnv(cfg, nn) # build taichi environment
#   File "/orion/u/yangyou/PlasticineLab/plb/optimizer/../../plb/engine/taichi_env.py", line 32, in __init__
#     self.renderer = Renderer(cfg.RENDERER, self.primitives)
#   File "/orion/u/yangyou/PlasticineLab/plb/optimizer/../../plb/engine/renderer/renderer.py", line 77, in __init__
#     ti.root.dense(ti.ijk, (4, 4, 4)).dense(ti.ijk, [i//4 for i in self.voxel_res]).place(self.volume, self.sdf, self.sdf_copy, self.color_vec)
# Shape 42 is detected on non-first division of axis j. For best performance, we recommend that you set it to a power of two.
# [W 12/31/23 19:30:03.649 1035681]
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/traitlets/config/application.py", line 1077, in launch_instance
#     app.start()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 737, in start
#     self.io_loop.start()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 524, in dispatch_queue
#     await self.process_one()
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 513, in process_one
#     await dispatch(*args)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 418, in dispatch_shell
#     await result
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 758, in execute_request
#     reply_content = await reply_content
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 426, in do_execute
#     res = shell.run_cell(
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/user/22715/ipykernel_1035681/1064780290.py", line 7, in <module>
#     env = make("Move-v1")
#   File "/orion/u/yangyou/PlasticineLab/plb/optimizer/../../plb/envs/__init__.py", line 17, in make
#     env: PlasticineEnv = gym.make(env_name, nn=nn)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/gym/envs/registration.py", line 156, in make
#     return registry.make(id, **kwargs)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/gym/envs/registration.py", line 101, in make
#     env = spec.make(**kwargs)
#   File "/orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/gym/envs/registration.py", line 73, in make
#     env = cls(**_kwargs)
#   File "/orion/u/yangyou/PlasticineLab/plb/optimizer/../../plb/envs/env.py", line 17, in __init__
#     self.taichi_env = TaichiEnv(cfg, nn) # build taichi environment
#   File "/orion/u/yangyou/PlasticineLab/plb/optimizer/../../plb/engine/taichi_env.py", line 32, in __init__
#     self.renderer = Renderer(cfg.RENDERER, self.primitives)
#   File "/orion/u/yangyou/PlasticineLab/plb/optimizer/../../plb/engine/renderer/renderer.py", line 77, in __init__
#     ti.root.dense(ti.ijk, (4, 4, 4)).dense(ti.ijk, [i//4 for i in self.voxel_res]).place(self.volume, self.sdf, self.sdf_copy, self.color_vec)
# Shape 42 is detected on non-first division of axis k. For best performance, we recommend that you set it to a power of two.
# [W 12/31/23 19:30:04.294 1035681]
# Assign may lose precision: unknown <- f32
# [W 12/31/23 19:30:04.341 1035681]
# Assign may lose precision: unknown <- f32
# [W 12/31/23 19:30:04.386 1035681]
# Assign may lose precision: unknown <- f32
# [W 12/31/23 19:30:04.492 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:04.538 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:04.586 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:04.644 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:04.958 1035681]
# Assign may lose precision: unknown <- f32
# [W 12/31/23 19:30:05.003 1035681]
# Assign may lose precision: unknown <- f32
# [W 12/31/23 19:30:05.047 1035681]
# Assign may lose precision: unknown <- f32
# [W 12/31/23 19:30:05.091 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:05.135 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:05.182 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:05.228 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:05.272 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:05.317 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:05.364 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:05.590 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:05.641 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:05.689 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:07.785 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:07.834 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:08.009 1035681]
# Assign may lose precision: unknown <- f64
# [W 12/31/23 19:30:08.058 1035681]
# Assign may lose precision: unknown <- f64
# /orion/u/yangyou/mambaforge/envs/torch2/lib/python3.10/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
def make_copy_and_clear_kernel(sim: plb.engine.mpm_simulator.MPMSimulator):
    @ti.kernel
    def copy_and_clear(f:ti.i32):
        for i in range(sim.n_particles):
            sim.x.grad[f, i] = sim.x.grad[0, i]
            sim.v.grad[f, i] = sim.v.grad[0, i]
            sim.F.grad[f, i] = sim.F.grad[0, i]
            sim.C.grad[f, i] = sim.C.grad[0, i]

        if ti.static(sim.n_primitive>0):
            for i in ti.static(range(sim.n_primitive)):
                sim.primitives[i].position.grad[f] = sim.primitives[i].position.grad[0]
                sim.primitives[i].rotation.grad[f] = sim.primitives[i].rotation.grad[0]


        for s in range(f):
            # clear
            if ti.static(sim.n_primitive>0):
                for i in ti.static(range(sim.n_primitive)):
                    for j in ti.static(range(3)):
                        sim.primitives[i].position.grad[s][j] = 0
                        sim.primitives[i].v.grad[s][j] = 0
                        sim.primitives[i].w.grad[s][j] = 0
                    for j in ti.static(range(4)):
                        sim.primitives[i].rotation.grad[s][j] = 0

        for i in range(sim.n_particles):
            for s in range(f):
                sim.x.grad[s, i] = ti.Vector.zero(sim.dtype, sim.dim)
                sim.v.grad[s, i] = ti.Vector.zero(sim.dtype, sim.dim)
                sim.F.grad[s, i] = ti.Vector.zero(sim.dtype, sim.dim, sim.dim)
                sim.C.grad[s, i] = ti.Vector.zero(sim.dtype, sim.dim, sim.dim)

    return copy_and_clear

_copy_and_clear = make_copy_and_clear_kernel(taichi_env.simulator)
def copy_and_clear(f):
    #for s in range(f//taichi_env.simulator.substeps+1):
    #    for i in taichi_env.primitives:
    #        i.action_buffer.grad[s] = [0, 0, 0]
    for i in taichi_env.primitives:
        i.action_buffer.grad.fill(0)
    _copy_and_clear(f)
copy_and_clear(21)

# %%
import taichi as ti
import numpy as np
from plb.engine.taichi_env import TaichiEnv
env.reset()
state = taichi_env.get_state()
sim_state = state['state']
actions = np.random.random(size=(50, 6))*0.01

def forward(taichi_env: TaichiEnv, sim_state, action):
    taichi_env.set_state(sim_state, 666, False)
    with ti.ad.Tape(loss=taichi_env.loss.loss):
        for i in range(len(action)):
            taichi_env.step(action[i])
            loss_info = taichi_env.compute_loss()
    loss = taichi_env.loss.loss[None]
    return loss, taichi_env.primitives.get_grad(len(action))

loss, grad = forward(taichi_env, sim_state, actions)

print(loss)
# Out:
# [W 12/31/23 19:30:29.411 1035681]
# Assign may lose precision: f32 <- f64
# [W 12/31/23 19:30:29.411 1035681]
# Assign may lose precision: f32 <- f64
# [W 12/31/23 19:30:29.411 1035681]
# Assign may lose precision: f32 <- f64
# [W 12/31/23 19:30:29.411 1035681]
# Assign may lose precision: f32 <- f64
# [W 12/31/23 19:30:29.411 1035681]
# Assign may lose precision: f32 <- f64
# [W 12/31/23 19:30:29.411 1035681]
# Assign may lose precision: f32 <- f64
# [W 12/31/23 19:30:29.411 1035681]
# Assign may lose precision: f32 <- f64
# [W 12/31/23 19:30:29.411 1035681]
# Assign may lose precision: f32 <- f64
# [W 12/31/23 19:30:29.411 1035681]
# Assign may lose precision: f32 <- f64
# [W 12/31/23 19:31:09.749 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1042 loaded in stmt 1043 before storing.
# [W 12/31/23 19:31:09.749 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1049 loaded in stmt 1050 before storing.
# [W 12/31/23 19:31:09.749 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1051 loaded in stmt 1052 before storing.
# [W 12/31/23 19:31:09.750 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1060 loaded in stmt 1061 before storing.
# [W 12/31/23 19:31:09.750 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1067 loaded in stmt 1068 before storing.
# [W 12/31/23 19:31:09.750 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1069 loaded in stmt 1070 before storing.
# [W 12/31/23 19:31:09.751 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1078 loaded in stmt 1079 before storing.
# [W 12/31/23 19:31:09.751 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1087 loaded in stmt 1088 before storing.
# [W 12/31/23 19:31:09.751 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1089 loaded in stmt 1090 before storing.
# [W 12/31/23 19:31:09.754 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1144 loaded in stmt 1145 before storing.
# [W 12/31/23 19:31:09.754 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1146 loaded in stmt 1147 before storing.
# [W 12/31/23 19:31:09.754 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1155 loaded in stmt 1156 before storing.
# [W 12/31/23 19:31:09.755 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1162 loaded in stmt 1163 before storing.
# [W 12/31/23 19:31:09.755 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1164 loaded in stmt 1165 before storing.
# [W 12/31/23 19:31:09.755 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1173 loaded in stmt 1174 before storing.
# [W 12/31/23 19:31:09.756 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1180 loaded in stmt 1181 before storing.
# [W 12/31/23 19:31:09.756 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1182 loaded in stmt 1183 before storing.
# [W 12/31/23 19:31:09.756 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1191 loaded in stmt 1192 before storing.
# [W 12/31/23 19:31:09.757 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1198 loaded in stmt 1199 before storing.
# [W 12/31/23 19:31:09.757 1036050] [control_flow_graph.cpp:get_store_forwarding_data@341] stmt 1200 loaded in stmt 1201 before storing.
# 663.295027964337

# %%
def forward2(taichi_env: TaichiEnv, init_state, action, T=12, compute_grad=True):
    max_timesteps = len(action)
    substeps = taichi_env.simulator.substeps

    checkpoints = {}
    loss = taichi_env.loss.loss
    total_loss = 0
    taichi_env.set_state(init_state, 666, False) #clear loss..

    with ti.ad.Tape(loss=loss):
        # clear grad and normal..
        pass
    for i in range(max_timesteps):
        if i % T == 0:
            state = init_state if i == 0 else taichi_env.simulator.get_state(T * substeps)
            checkpoints[i] = state
            total_loss += loss[None]
            taichi_env.set_state(checkpoints[i], 666, False) #set_state clears loss
        taichi_env.step(action[i])
        taichi_env.compute_loss()
    total_loss += loss[None]

    if compute_grad:
        total_loss2 = loss[None]

        action_grads = []
        last = max_timesteps
        for i in range(max_timesteps-1, -1, -1):
            f = (i % T) * substeps
            taichi_env.loss.compute_loss_kernel.grad(taichi_env.loss, f + substeps)
            for s in reversed(range(f, f+substeps)):
                taichi_env.simulator.substep_grad(s)
            # no gradient for set action..
            for p in taichi_env.primitives:
                p.set_velocity.grad(i % T, substeps)

            if i % T == 0:
                action_grads.append(taichi_env.primitives.get_grad(last-i))
                last = i

                if i > 0:
                    start = ((i - 1) // T) * T
                    taichi_env.set_state(checkpoints[start], 666, False)
                    for s in range(start, i):
                        taichi_env.step(action[s])
                        taichi_env.compute_loss()

                    total_loss2 += loss[None]
                    copy_and_clear(T * substeps)

    return total_loss, np.concatenate(action_grads[::-1])

loss2, grad2 = forward2(taichi_env, sim_state, actions, T=5, compute_grad=True)

assert np.allclose(loss, loss2)
print(abs(grad -grad2).max())
assert abs(grad2 - grad).max() < 1e-4
# Out:
# 4.688574312572413e-06
